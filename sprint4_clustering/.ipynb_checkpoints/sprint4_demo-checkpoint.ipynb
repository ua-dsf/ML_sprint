# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.utils import shuffle
from sklearn.utils import check_random_state
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.metrics import pairwise_distances                 
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

from scipy.sparse import csr_matrix 

import pandas as pd
import numpy as np
import sys      
import os
# %matplotlib inline

# %% [markdown]
# # Task1: Understanding initialization impact on convergence

# %%
random_state = np.random.RandomState(0)

# Number of run (with randomly generated dataset) for each strategy so as
# to be able to compute an estimate of the standard deviation
n_runs = 10

# Number of time the k-means algorithm will be run with different
# centroid seeds. The final results will be the best output of n_init consecutive runs in terms of inertia.
n_init_range = np.array([1, 5, 10, 15, 20])

# Datasets generation parameters
n_samples_per_center = 100
grid_size = 3
scale = 0.1
n_clusters = grid_size ** 2

def make_data(random_state, n_samples_per_center, grid_size, scale):
    random_state = check_random_state(random_state)
    centers = np.array([[i, j]
                        for i in range(grid_size)
                        for j in range(grid_size)])
    n_clusters_true, n_features = centers.shape

    noise = random_state.normal(
        scale=scale, size=(n_samples_per_center, centers.shape[1]))

    X = np.concatenate([c + noise for c in centers])
    y = np.concatenate([[i] * n_samples_per_center
                        for i in range(n_clusters_true)])
    return shuffle(X, y, random_state=random_state)

# %%
# Part 1: Quantitative evaluation of various init methods

plt.figure()
plots = []
legends = []

cases = [
    (KMeans, 'k-means++', {}),
    (KMeans, 'random', {}),
]

for factory, init, params in cases:
    print("Evaluation of %s with %s init" % (factory.__name__, init))
    inertia = np.empty((len(n_init_range), n_runs))

    for run_id in range(n_runs):
        X, y = make_data(run_id, n_samples_per_center, grid_size, scale)
        for i, n_init in enumerate(n_init_range):
            km = factory(n_clusters=n_clusters, init=init, random_state=run_id,
                         n_init=n_init, **params).fit(X)
            inertia[i, run_id] = km.inertia_
    p = plt.errorbar(n_init_range, inertia.mean(axis=1), inertia.std(axis=1))
    plots.append(p[0])
    legends.append("%s with %s init" % (factory.__name__, init))

plt.xlabel('n_init')
plt.ylabel('inertia')
plt.legend(plots, legends)
plt.title("Mean inertia for various k-means init across %d runs" % n_runs)
# Out:
# Evaluation of KMeans with k-means++ init
# Evaluation of KMeans with random init
# Text(0.5,1,'Mean inertia for various k-means init across 10 runs')

# %%
# Part 2: Qualitative visual inspection of the convergence

X, y = make_data(random_state, n_samples_per_center, grid_size, scale)
km = KMeans(n_clusters=n_clusters, init='random', n_init=1,
                     random_state=random_state).fit(X)
# init can be used with 'random' or the 'k-means++'

plt.figure()
for k in range(n_clusters):
    my_members = km.labels_ == k
    color = cm.nipy_spectral(float(k) / n_clusters, 1)
    plt.plot(X[my_members, 0], X[my_members, 1], 'o', marker='.', c=color)
    cluster_center = km.cluster_centers_[k]
    plt.plot(cluster_center[0], cluster_center[1], 'o',
             markerfacecolor=color, markeredgecolor='k', markersize=6)
    plt.title("Example cluster allocation with a random init\n"
              "with KMeans")

plt.show()

# %% [markdown]
# # Task 2: Use k-means to cluster wikipedia articles

# %% [markdown]
# ## Compute TF-IDF

# %%
# import text documents from wikipedia abstracts
wiki_data=pd.read_csv('new_zeland_people.tsv',delimiter='\t', index_col='name')['abstract']

wiki_data.head()
# Out:
# name
# A. R. D. Fairburn       "Arthur Rex Dugard "Rex" Fairburn (2 February ...
# Aaran Franklyn Lines    "Aaran Franklyn Lines (born 21 December 1976 i...
# Aaran Lines             "Aaran Franklyn Lines (born 21 December 1976 i...
# Aaron Gate              "Aaron Gate (born 26 November 1990) is a New Z...
# Aaron Harper            "Aaron David Harper (born 20 May 1967) is an A...
# Name: abstract, dtype: object

# %%
#Define the TFIDF vectorizer that will be used to process the data
tfidf_vectorizer = TfidfVectorizer()
#Apply this vectorizer to the full dataset to create normalized vectors
tfidf_matrix = tfidf_vectorizer.fit_transform(wiki_data)

# %%
#normalize the tfidfmatrix
tf_idf = normalize(tfidf_matrix)

# %% [markdown]
# ## Choose the right number of k

# %%
def plot_k_vs_heterogeneity(k_values, heterogeneity_values):
    plt.figure(figsize=(7,4))
    plt.plot(k_values, heterogeneity_values, linewidth=4)
    plt.xlabel('K')
    plt.ylabel('Inertia')
    plt.title('K vs. Inertia')
    plt.rcParams.update({'font.size': 16})
    plt.tight_layout()

# %%
heterogeneity_values = []
k_list = [2, 10, 25, 50, 100, 300]

# %%
for n_clusters in k_list:
    km = KMeans(n_clusters=n_clusters, init='k-means++').fit(tf_idf)
    heterogeneity_values.append(km.inertia_)

# %%
plot_k_vs_heterogeneity(k_list, heterogeneity_values)

# %%
# compute kmeans using random initialization
kmeans = KMeans(n_clusters=100, init='random').fit(tf_idf) # init can be used with 'random' or the 'k-means++' 
# predict the closest cluster for each point
labels= kmeans.predict(tf_idf)

# %%
# retrieve other pages from a cluster
def get_cluster(cluster_nb, labels, dataset):
    curr_cluster=[]
    abstract=[]
    for index in range(len(labels)):
        if labels[index]==cluster_nb:
            curr_cluster.append(dataset.index.values[index,])
            abstract.append(dataset.iloc[index,])
            
    result = pd.DataFrame({'names': curr_cluster,
                           'abstract': abstract})
    return result

# %%
# Find the cluster in which Taika Waititi is
pos = wiki_data.index.get_loc("Taika Waititi")
labels[pos]
# Out:
# 66

# %%
cluster= get_cluster(labels[pos], labels, wiki_data)
cluster
# Out:
#                      names                                           abstract
# 0           Andrew Adamson  "Andrew Ralph Adamson, MNZM (born 1 December 1...
# 1            Andrew Niccol  "Andrew M. Niccol (born 10 June 1964) is a New...
# 2        Angela Bloomfield  "Angela Bloomfield (born 11 December 1972) is ...
# 3   Barbara Sumner-Burstyn  "Barbara Sumner Burstyn is a film producer and...
# 4         Bartholomew John  "Bartholomew John (born 24 August 1952 in Chri...
# 5             Bill Stalker  "William Robert "Bill" Stalker (3 August 1948 ...
# 6          Bridgette Allen  "Bridgette Allen is a New Zealand born Jazz si...
# 7           Bruce Allpress  "Bruce Robert Allpress (born 25 August 1930) i...
# 8            Bruce Hopkins  "Raymond Bruce Hopkins (born 25 November 1955)...
# 9             Bruce Spence  "Bruce Spence (born 17 September 1945) is a Ne...
# 10          Cameron Duncan  "Cameron Troy Duncan (20 April 1986 Ð 12 Novem...
# 11          Cameron Rhodes  "Cameron Rhodes (born 1 August 1967) is an fil...
# 12         Charles Bennett  "Charles Bennett (11 March 1889 Ð 15 February ...
# 13           Charles Eyton  "Charles Eyton (New Zealand, 24 June 1871 Ð Ho...
# 14   Colin Mathura-Jeffree  "Colin Mathura-Jeffree (born 12 May 1972) is a...
# 15              Craig Hall  "Craig Hall (born 10 May 1974) is a New Zealan...
# 16           Damon Andrews  "Damon Andrews (born 28 October 1971) is a dir...
# 17            Daniel Logan  "Daniel Logan (born 6 June 1987) is a New Zeal...
# 18              Dave Comer  "David John "Dave" Comer (26 July 1956 Ð 25 De...
# 19         David Donaldson  "David Donaldson (born 1960) is a New Zealand ...
# 20            David Hannay  "David Hannay (23 June 1939 Ð 31 March 2014) w...
# 21           David Warbeck  "David Warbeck (born David Mitchell; 17 Novemb...
# 22           Dean O'Gorman  "Dean Lance O'Gorman (born 1 December 1976) is...
# 23            Dean Wareham  "Michael Dean Wareham (born 1 August 1963) is ...
# 24         Elizabeth Moody  "Elizabeth Moody (nŽe Bromley, 29 October 1939...
# 25       Elsie Jane Wilson  "Elsie Jane Wilson (7 November 1885 Ð 16 Janua...
# 26           Frank Whitten  "Frank Edgar Richard Whitten (15 November 1942...
# 27            Gabriel Reid  "Gabriel Luke Reid (born 24 February 1969) is ...
# 28         Gareth Williams  "Gareth Williams (born 13 July 1984) is a New ...
# 29           Garth Maxwell  "Garth Maxwell (born 1963) is a New Zealand fi...
# ..                     ...                                                ...
# 45            Lucy Wigmore  "Lucy Wigmore is a stage and screen actress fr...
# 46             Mark Hadlow  "Mark Hadlow (born 1957) is a New Zealand acto...
# 47         Marshall Napier  "Marshall James Napier is a New Zealand-born a...
# 48         Michael Bennett  "Michael Te Arawa Bennett is a New Zealand wri...
# 49            Mike Hopkins  "Michael Alexander "Mike" Hopkins (12 August 1...
# 50               Niki Caro  "Nikola Jean "Niki" Caro MNZM (born 1967) is a...
# 51              Nina Byron  "Nina Byron (born July 27, 1900, date of death...
# 52           Oliver Driver  "Oliver Driver (born 22 November 1974) is a Ne...
# 53             Paul McIver  "Paul McIver (born 26 March 1986) is an actor ...
# 54         Peter Hambleton  "Peter Hambleton (born 1960) is a New Zealand ...
# 55            Peter Rowley  "Peter Rowley (born 1952) (sometimes credited ...
# 56            Rachel House  "Rachel House is a New Zealand actress, direct...
# 57            Rene Naufahu  "Rene Naufahu (born May 1970) is a New Zealand...
# 58          Richard Taylor  "Sir Richard Leslie Taylor KNZM is the founder...
# 59      Sir Richard Taylor  "Sir Richard Leslie Taylor KNZM is the founder...
# 60             Riwia Brown  "Riwia Brown is a playwright and the award win...
# 61          Robert Pollock  "Robert Pollock (born 1960) is a New Zealand a...
# 62            Roger Mirams  "Roger Eastgate Holden Mirams (16 April 1918 Ð...
# 63            Roger Oakley  "Roger Oakley (born 21 August 1943, Auckland) ...
# 64             Roy Billing  "Roy Harwood Billing OAM is a New Zealand tele...
# 65           Russell Crowe  "Russell Ira Crowe (born 7 April 1964) is an a...
# 66           Shayne Biddle  "Shayne Biddle is a New Zealand actor, best kn...
# 67          Stephen Hunter  "Stephen John Hunter (born October 28, 1968) i...
# 68             Stephen Kay  "Stephen T. Kay (born 1963) is a New Zealand a...
# 69             Steve Roche  "Steve Roche (Stephen) (born 1964) is a New Ze...
# 70          Stuart Devenie  "Stuart Forbes Devenie, MNZM, is an actor and ...
# 71           Taika Waititi  "Taika David Waititi (born 16 August 1975), al...
# 72            Vincent Klyn  "Vincent Klyn (born June 30, 1960) is a New Ze...
# 73             Wi Kuki Kaa  "Wi Kuki Kaa (16 December 1938 Ð 19 February 2...
# 74             Winter Hall  "Winter Hall (21 June 1872 Ð 10 February 1947)...
#
# [75 rows x 2 columns]

# %% [markdown]
# # LDA modeling

# %%
# import text documents from wikipedia abstracts
wiki_data=pd.read_csv('new_zeland_people.tsv',delimiter='\t', index_col='name')['abstract']

wiki_data.head()
# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
tf = tf_vectorizer.fit_transform(wiki_data)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
no_topics = 20
# Run LDA
lda = LatentDirichletAllocation(n_topics=no_topics).fit(tf)
# Out:
# /Users/aponsero/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:314: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %% [markdown]
# # Display and evaluate topics

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# new zealand born year m_ori month playboy following gorst july
# Topic 1:
# new zealand born team played blacks rugby league member wellington
# Topic 2:
# new zealand international football represented player played official matches level
# Topic 3:
# party minister labour politician new parliament zealand served government election
# Topic 4:
# new zealand university band born album released world young auckland
# Topic 5:
# new zealand wrestling holmes canadian international australia born championship 2009
# Topic 6:
# new zealand born music wellington court auckland years member work
# Topic 7:
# university cambridge groves oxford darts new professor john january zealand
# Topic 8:
# rugby union born plays new zealand currently cup player super
# Topic 9:
# new zealand born national professional plays wrestling league footballer team
# Topic 10:
# new zealand born team world won games olympics championships netball
# Topic 11:
# new zealand hockey born field 1956 olympic games auckland university
# Topic 12:
# new zealand born fashion wrestling wellington air glasgow june played
# Topic 13:
# new zealand international represented level football official association player appearance
# Topic 14:
# new artist zealand mixed martial born known ufc world thomson
# Topic 15:
# new zealand born film actor known television best series role
# Topic 16:
# new zealand played cricket cricketer class test born match matches
# Topic 17:
# international new zealand football represented player loss association level career
# Topic 18:
# new zealand born australia australian known art james january work
# Topic 19:
# new zealand born played wellington national league team bracewell australian

# %%
# transform method returns a matrix with one line per document, columns being topics weight
predict = lda.transform(tf)
result = pd.DataFrame(predict).set_index(wiki_data.reset_index()['name'])

# %%
# get distribution of topics for an article
result.loc["Taika Waititi"]
# Out:
# 0     0.001190
# 1     0.001190
# 2     0.001190
# 3     0.001190
# 4     0.001190
# 5     0.001190
# 6     0.001190
# 7     0.001190
# 8     0.001190
# 9     0.001190
# 10    0.001190
# 11    0.001190
# 12    0.001190
# 13    0.001190
# 14    0.001190
# 15    0.977381
# 16    0.001190
# 17    0.001190
# 18    0.001190
# 19    0.001190
# Name: Taika Waititi, dtype: float64

# %%
d = pd.Series(result.loc["Taika Waititi"]).sort_values(ascending=False)

ax = d.plot(kind='bar', title='Taika Waititi Wikipedia Topic distribution',
            figsize=(10,6), width=.8, fontsize=14, rot=45 )

ax.title.set_size(20)

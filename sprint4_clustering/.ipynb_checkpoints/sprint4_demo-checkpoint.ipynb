# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.utils import shuffle
from sklearn.utils import check_random_state
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.metrics import pairwise_distances                 
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import make_blobs

from scipy.sparse import csr_matrix 

import pandas as pd
import numpy as np
import sys      
import os
# %matplotlib inline

# %% [markdown]
# # Running kmeans in sci-kit learn

# %%
n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)

plt.scatter(X[:, 0], X[:, 1])
plt.title("Create random blobs")
# Out:
# Text(0.5,1,'Create random blobs')

# %%
# Incorrect number of clusters
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")
# Out:
# Text(0.5,1,'Incorrect Number of Blobs')

# %%
# Incorrect number of clusters
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("correct Number of Blobs")
# Out:
# Text(0.5,1,'correct Number of Blobs')

# %% [markdown]
# # Task1: Understanding initialization impact on convergence

# %%
random_state = np.random.RandomState(0)

# Datasets generation parameters
n_samples_per_center = 100
grid_size = 3
scale = 0.1
n_clusters = grid_size ** 2

def make_data(random_state, n_samples_per_center, grid_size, scale):
    random_state = check_random_state(random_state)
    centers = np.array([[i, j]
                        for i in range(grid_size)
                        for j in range(grid_size)])
    n_clusters_true, n_features = centers.shape

    noise = random_state.normal(
        scale=scale, size=(n_samples_per_center, centers.shape[1]))

    X = np.concatenate([c + noise for c in centers])
    y = np.concatenate([[i] * n_samples_per_center
                        for i in range(n_clusters_true)])
    return shuffle(X, y, random_state=random_state)

# %% [markdown]
# ## Kmeans initialisation effect

# %%
X, y = make_data(random_state, n_samples_per_center, grid_size, scale)
km = KMeans(n_clusters=n_clusters, init='random', n_init=1,
                     random_state=random_state).fit(X)

plt.figure()
for k in range(n_clusters):
    my_members = km.labels_ == k
    color = cm.nipy_spectral(float(k) / n_clusters, 1)
    plt.plot(X[my_members, 0], X[my_members, 1], 'o', marker='.', c=color)
    cluster_center = km.cluster_centers_[k]
    plt.plot(cluster_center[0], cluster_center[1], 'o',
             markerfacecolor=color, markeredgecolor='k', markersize=6)
    plt.title("Example cluster allocation with a random init\n"
              "with KMeans")

plt.show()

# %%
X, y = make_data(random_state, n_samples_per_center, grid_size, scale)
km = KMeans(n_clusters=n_clusters, init='k-means++', n_init=1,
                     random_state=random_state).fit(X)

plt.figure()
for k in range(n_clusters):
    my_members = km.labels_ == k
    color = cm.nipy_spectral(float(k) / n_clusters, 1)
    plt.plot(X[my_members, 0], X[my_members, 1], 'o', marker='.', c=color)
    cluster_center = km.cluster_centers_[k]
    plt.plot(cluster_center[0], cluster_center[1], 'o',
             markerfacecolor=color, markeredgecolor='k', markersize=6)
    plt.title("Example cluster allocation with a random init\n"
              "with KMeans")

plt.show()

# %% [markdown]
# ## Inertia measure

# %%
# Number of time the k-means algorithm will be run with different
# centroid seeds. The final results will be the best output of n_init consecutive runs in terms of inertia.
n_init_range = np.array([1, 5, 10, 15, 20])

# Number of run (with randomly generated dataset) for each strategy so as
# to be able to compute an estimate of the standard deviation
n_runs = 10

plt.figure()
plots = []
legends = []

cases = [
    (KMeans, 'k-means++', {}),
    (KMeans, 'random', {}),
]

for factory, init, params in cases:
    print("Evaluation of %s with %s init" % (factory.__name__, init))
    inertia = np.empty((len(n_init_range), n_runs))

    for run_id in range(n_runs):
        X, y = make_data(run_id, n_samples_per_center, grid_size, scale)
        for i, n_init in enumerate(n_init_range):
            km = factory(n_clusters=n_clusters, init=init, random_state=run_id,
                         n_init=n_init, **params).fit(X)
            inertia[i, run_id] = km.inertia_
    p = plt.errorbar(n_init_range, inertia.mean(axis=1), inertia.std(axis=1))
    plots.append(p[0])
    legends.append("%s with %s init" % (factory.__name__, init))

plt.xlabel('n_init')
plt.ylabel('inertia')
plt.legend(plots, legends)
plt.title("Mean inertia for various k-means init across %d runs" % n_runs)
# Out:
# Evaluation of KMeans with k-means++ init
# Evaluation of KMeans with random init
# Text(0.5,1,'Mean inertia for various k-means init across 10 runs')

# %% [markdown]
# # Task 2: Use k-means to cluster wikipedia articles

# %% [markdown]
# ## Compute TF-IDF

# %%
# import text documents from wikipedia abstracts
wiki_data=pd.read_csv('new_zeland_people.tsv',delimiter='\t', index_col='name')['abstract']

wiki_data.head()
# Out:
# name
# A. R. D. Fairburn       "Arthur Rex Dugard "Rex" Fairburn (2 February ...
# Aaran Franklyn Lines    "Aaran Franklyn Lines (born 21 December 1976 i...
# Aaran Lines             "Aaran Franklyn Lines (born 21 December 1976 i...
# Aaron Gate              "Aaron Gate (born 26 November 1990) is a New Z...
# Aaron Harper            "Aaron David Harper (born 20 May 1967) is an A...
# Name: abstract, dtype: object

# %%
#Define the TFIDF vectorizer that will be used to process the data
tfidf_vectorizer = TfidfVectorizer()
#Apply this vectorizer to the full dataset to create normalized vectors
tf_idf = tfidf_vectorizer.fit_transform(wiki_data)

# %% [markdown]
# ## Choose the right number of k

# %%
def plot_k_vs_heterogeneity(k_values, heterogeneity_values):
    plt.figure(figsize=(7,4))
    plt.plot(k_values, heterogeneity_values, linewidth=4)
    plt.xlabel('K')
    plt.ylabel('Inertia')
    plt.title('K vs. Inertia')
    plt.rcParams.update({'font.size': 16})
    plt.tight_layout()

# %%
heterogeneity_values = []
k_list = [2, 10, 25, 50, 100, 300]

# %%
for n_clusters in k_list:
    km = KMeans(n_clusters=n_clusters, init='k-means++').fit(tf_idf)
    heterogeneity_values.append(km.inertia_)

# %%
plot_k_vs_heterogeneity(k_list, heterogeneity_values)

# %%
# compute kmeans using random initialization
kmeans = KMeans(n_clusters=100, init='random').fit(tf_idf)  
# predict the closest cluster for each point
labels= kmeans.predict(tf_idf)

# %%
# retrieve other pages from a cluster
def get_cluster(cluster_nb, labels, dataset):
    curr_cluster=[]
    abstract=[]
    for index in range(len(labels)):
        if labels[index]==cluster_nb:
            curr_cluster.append(dataset.index.values[index,])
            abstract.append(dataset.iloc[index,])
            
    result = pd.DataFrame({'names': curr_cluster,
                           'abstract': abstract})
    return result

# %%
# Find the cluster in which Taika Waititi is
pos = wiki_data.index.get_loc("Taika Waititi")
labels[pos]
# Out:
# 23

# %%
cluster= get_cluster(labels[pos], labels, wiki_data)
cluster
# Out:
#                       names                                           abstract
# 0     Alfred Charles Hanlon  "Alfred Charles "Alf" Hanlon KC (1 August 1866...
# 1              Alison James  "Alison James (born 31 March 1971), is a New Z...
# 2               Alison Wall  "Alison Wall (born 1966 in Auckland, New Zeala...
# 3             Alix Bushnell  "Alix Bushnell (born 1983) is a New Zealand ac...
# 4          Amber McWilliams  "Amber McWilliams is a New Zealand actress, be...
# 5              Amy Morrison  "Amy Morrison (born 18 July 1984) is a New Zea...
# 6              Andrew Laing  "Andrew Laing (born 1966) is a New Zealand act...
# 7             Andrew Niccol  "Andrew M. Niccol (born 10 June 1964) is a New...
# 8            Angela Dotchin  "Angela Marie Dotchin (born 31 March 1974 in A...
# 9            Anna Jullienne  "Anna Jullienne Kermode (born 7 November 1982)...
# 10   Anna Jullienne Kermode  "Anna Jullienne Kermode (born 7 November 1982)...
# 11          Antonia Prebble  "Antonia Mary Prebble (born 6 June 1984, in We...
# 12   Barbara Sumner-Burstyn  "Barbara Sumner Burstyn is a film producer and...
# 13         Bartholomew John  "Bartholomew John (born 24 August 1952 in Chri...
# 14           Ben Barrington  "Ben Barrington is a New Zealand actor, is bes...
# 15        Benjamin Mitchell  "(For other people with the same name, see Ben...
# 16            Bettina Welch  "Bettina Catherine Welch (1922 Ð 5 March 1993)...
# 17            Bronwyn Turei  "Bronwyn Turei is a New Zealand actress and si...
# 18          Brooke Williams  "Brooke Williams (born 3 January 1984) is a Ne...
# 19           Bruce Allpress  "Bruce Robert Allpress (born 25 August 1930) i...
# 20            Bruce Hopkins  "Raymond Bruce Hopkins (born 25 November 1955)...
# 21           Cameron Rhodes  "Cameron Rhodes (born 1 August 1967) is an fil...
# 22           Claire Chitham  "Claire Chitham (born 12 July 1978 in Auckland...
# 23             Cliff Curtis  "Clifford Vivian Devon "Cliff" Curtis (born 27...
# 24           Courtney Abbot  "Courtney Abbot (born November 15, 1989) is a ...
# 25             Daniel Logan  "Daniel Logan (born 6 June 1987) is a New Zeal...
# 26          David Donaldson  "David Donaldson (born 1960) is a New Zealand ...
# 27             David Hannay  "David Hannay (23 June 1939 Ð 31 March 2014) w...
# 28            David Warbeck  "David Warbeck (born David Mitchell; 17 Novemb...
# 29            Dayna Vawdrey  "Dayna Vawdrey is a New Zealand television pre...
# ..                      ...                                                ...
# 106            Roger Mirams  "Roger Eastgate Holden Mirams (16 April 1918 Ð...
# 107            Roger Oakley  "Roger Oakley (born 21 August 1943, Auckland) ...
# 108            Roz Turnbull  "Roz Turnbull (born 1972) is a New Zealand act...
# 109           Russell Crowe  "Russell Ira Crowe (born 7 April 1964) is an a...
# 110            Sally Martin  "Sally Erana Martin (born May 14, 1985) is an ...
# 111            Sara Wiseman  "Sara Wiseman is a New Zealand actress known f...
# 112             Sarah Major  "Sarah Major (born August 22, 1988) is a voice...
# 113           Sarah Thomson  "Sarah Thomson (born June 17, 1985) is a New Z...
# 114           Scott Harding  "Scott Harding (born 2 March 1971) is a New Ze...
# 115           Shane Cortese  "Shane Cortese (born 13 August 1968) is a New ...
# 116           Shayne Biddle  "Shayne Biddle is a New Zealand actor, best kn...
# 117          Simone Kessell  "Simone Kessell (born 1975) is a New Zealand-b...
# 118          Stephen Hunter  "Stephen John Hunter (born October 28, 1968) i...
# 119             Stephen Kay  "Stephen T. Kay (born 1963) is a New Zealand a...
# 120             Steve Roche  "Steve Roche (Stephen) (born 1964) is a New Ze...
# 121          Stuart Devenie  "Stuart Forbes Devenie, MNZM, is an actor and ...
# 122             Susan Brady  "Susan Brady (born 2 March 1966) is a New Zeal...
# 123           Taika Waititi  "Taika David Waititi (born 16 August 1975), al...
# 124             Tania Nolan  "Tania Nolan (born 19 August 1983) is an actre...
# 125        Temuera Morrison  "Temuera Derek Morrison MNZM (born 26 December...
# 126          Theresa Healey  "Theresa Healey is a New Zealand actress, know...
# 127               Tim Balme  "Timothy Guy Balme (born 1967) is an actor and...
# 128             Todd Rippon  "Todd Rippon (born May 30, 1964) is a film and...
# 129        Victoria Schmidt  "Victoria Schmidt is a New Zealand theater, fi...
# 130            Vincent Klyn  "Vincent Klyn (born June 30, 1960) is a New Ze...
# 131        Virginie Le Brun  "Virginie Le Brun (born 7 June 1980) is a New ...
# 132             Wi Kuki Kaa  "Wi Kuki Kaa (16 December 1938 Ð 19 February 2...
# 133           Willa O'Neill  "Willa O'Neill is an award-winning actress fro...
# 134             Zara Nutley  "Zara Nutley (born 12 June 1926) is a British ...
# 135                Zo‘ Bell  "Zo‘ E. Bell (born 17 November 1978) is a New ...
#
# [136 rows x 2 columns]

# %%
# smarter initialization
# compute kmeans using random initialization
kmeans = KMeans(n_clusters=50, init='k-means++').fit(tf_idf)  
# predict the closest cluster for each point
labels= kmeans.predict(tf_idf)
# Find the cluster in which Taika Waititi is
pos = wiki_data.index.get_loc("Taika Waititi")
labels[pos]
# get cluster
cluster= get_cluster(labels[pos], labels, wiki_data)
cluster
# Out:
#                      names                                           abstract
# 0            Andrew Niccol  "Andrew M. Niccol (born 10 June 1964) is a New...
# 1   Barbara Sumner-Burstyn  "Barbara Sumner Burstyn is a film producer and...
# 2           Bruce Allpress  "Bruce Robert Allpress (born 25 August 1930) i...
# 3            Bruce Hopkins  "Raymond Bruce Hopkins (born 25 November 1955)...
# 4           Cameron Rhodes  "Cameron Rhodes (born 1 August 1967) is an fil...
# 5          Charles Bennett  "Charles Bennett (11 March 1889 Ð 15 February ...
# 6            Charles Eyton  "Charles Eyton (New Zealand, 24 June 1871 Ð Ho...
# 7           Courtney Abbot  "Courtney Abbot (born November 15, 1989) is a ...
# 8            Damon Andrews  "Damon Andrews (born 28 October 1971) is a dir...
# 9             Daniel Logan  "Daniel Logan (born 6 June 1987) is a New Zeal...
# 10         David Donaldson  "David Donaldson (born 1960) is a New Zealand ...
# 11            David Hannay  "David Hannay (23 June 1939 Ð 31 March 2014) w...
# 12           David Warbeck  "David Warbeck (born David Mitchell; 17 Novemb...
# 13             Donogh Rees  "Donogh Rees (born 1959) is a New Zealand actr...
# 14         Elizabeth Moody  "Elizabeth Moody (nŽe Bromley, 29 October 1939...
# 15       Elsie Jane Wilson  "Elsie Jane Wilson (7 November 1885 Ð 16 Janua...
# 16            Gabriel Reid  "Gabriel Luke Reid (born 24 February 1969) is ...
# 17           Garth Maxwell  "Garth Maxwell (born 1963) is a New Zealand fi...
# 18         Gaylene Preston  "Gaylene Preston, ONZM (born 1 June 1947) is a...
# 19           Ivar Campbell  "Ivar Campbell (born 1904, died 1985), full na...
# 20            Jacob Tomuri  "Jacob Tomuri (born 4 December 1979) is a New ...
# 21  James Napier Robertson  "James William Napier Robertson (born 24 March...
# 22           Jamie Selkirk  "Jamie Selkirk is a film editor and producer w...
# 23              Jed Brophy  "Jed Brophy (born 1963, Feilding) is a film ac...
# 24         Julian Arahanga  "Julian Arahanga (born 18 December 1972) is a ...
# 25         Julian Dennison  "Julian Dennison (born 16 Oct 2002) is a New Z...
# 26           Kevin Taumata  "Kevin James Taumata is a M_ori New Zealander ...
# 27         Marshall Napier  "Marshall James Napier is a New Zealand-born a...
# 28         Michael Bennett  "Michael Te Arawa Bennett is a New Zealand wri...
# 29          Michael Hedges  "Michael Hedges is a sound engineer from Welli...
# 30            Mike Hopkins  "Michael Alexander "Mike" Hopkins (12 August 1...
# 31        Morgana O'Reilly  "Morgana O'Reilly (born 19 August 1985) is a N...
# 32               Niki Caro  "Nikola Jean "Niki" Caro MNZM (born 1967) is a...
# 33              Nina Byron  "Nina Byron (born July 27, 1900, date of death...
# 34             Paul McIver  "Paul McIver (born 26 March 1986) is an actor ...
# 35         Peter Hambleton  "Peter Hambleton (born 1960) is a New Zealand ...
# 36            Rene Naufahu  "Rene Naufahu (born May 1970) is a New Zealand...
# 37          Richard Curtis  "(For other people named Richard Curtis, see R...
# 38             Riwia Brown  "Riwia Brown is a playwright and the award win...
# 39            Roger Mirams  "Roger Eastgate Holden Mirams (16 April 1918 Ð...
# 40            Roger Oakley  "Roger Oakley (born 21 August 1943, Auckland) ...
# 41           Russell Crowe  "Russell Ira Crowe (born 7 April 1964) is an a...
# 42           Shayne Biddle  "Shayne Biddle is a New Zealand actor, best kn...
# 43          Stephen Hunter  "Stephen John Hunter (born October 28, 1968) i...
# 44             Stephen Kay  "Stephen T. Kay (born 1963) is a New Zealand a...
# 45             Steve Roche  "Steve Roche (Stephen) (born 1964) is a New Ze...
# 46          Stuart Devenie  "Stuart Forbes Devenie, MNZM, is an actor and ...
# 47           Taika Waititi  "Taika David Waititi (born 16 August 1975), al...
# 48        Temuera Morrison  "Temuera Derek Morrison MNZM (born 26 December...
# 49            Vincent Klyn  "Vincent Klyn (born June 30, 1960) is a New Ze...
# 50             Wi Kuki Kaa  "Wi Kuki Kaa (16 December 1938 Ð 19 February 2...
# 51           Willa O'Neill  "Willa O'Neill is an award-winning actress fro...
# 52                Zo‘ Bell  "Zo‘ E. Bell (born 17 November 1978) is a New ...

# %% [markdown]
# # LDA modeling

# %%
# import text documents from wikipedia abstracts
wiki_data=pd.read_csv('new_zeland_people.tsv',delimiter='\t', index_col='name')['abstract']

wiki_data.head()
# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
tf = tf_vectorizer.fit_transform(wiki_data)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
no_topics = 20
# Run LDA
lda = LatentDirichletAllocation(n_topics=no_topics).fit(tf)
# Out:
# /Users/aponsero/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:314: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %% [markdown]
# # Display and evaluate topics

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# new zealand known born wrestling best australian professional film young
# Topic 1:
# known television new actor zealand actress born role series best
# Topic 2:
# new zealand born 2015 team test debut australian player australia
# Topic 3:
# university professor wrestling new research zealand college book canadian fellow
# Topic 4:
# new netball zealand ferns born anz championship silver played season
# Topic 5:
# new zealand born university member council minister government september united
# Topic 6:
# new zealand born won olympics games world summer team medal
# Topic 7:
# zealand new history november banks war born world known sikh
# Topic 8:
# new zealand vance british gorst born jackson general hobbit egypt
# Topic 9:
# new zealand beattie born cup youth took world brown hutchison
# Topic 10:
# new zealand born wilson june williams boyd auckland 1942 1934
# Topic 11:
# university match class new season cambridge zealand groves born oxford
# Topic 12:
# new zealand played cricket cricketer class born test matches match
# Topic 13:
# international new zealand football represented level player association loss win
# Topic 14:
# new zealand born rugby plays player team union league professional
# Topic 15:
# new zealand born miss court international world february james march
# Topic 16:
# new zealand party born politician radio parliament member labour james
# Topic 17:
# zealand new test played matches match took england second tour
# Topic 18:
# new zealand born world cup hockey field games represented fifa
# Topic 19:
# new zealand born women film television world group china appeared

# %%
# transform method returns a matrix with one line per document, columns being topics weight
predict = lda.transform(tf)
result = pd.DataFrame(predict).set_index(wiki_data.reset_index()['name'])

# %%
# get distribution of topics for Taika Waititi
d = pd.Series(result.loc["Taika Waititi"]).sort_values(ascending=False)

ax = d.plot(kind='bar', title='Taika Waititi Wikipedia Topic distribution',
            figsize=(10,6), width=.8, fontsize=14, rot=45 )

ax.title.set_size(20)

# %%
# Adjust (less or more topics) and rerun the LDA model
no_topics = 10
# Run LDA
lda = LatentDirichletAllocation(n_topics=no_topics).fit(tf)
# Out:
# /Users/aponsero/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:314: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %%
no_top_words = 10
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# new zealand born team world rugby player netball cup national
# Topic 1:
# new zealand born known best wrestling professional world series auckland
# Topic 2:
# new zealand born known television film actor best series role
# Topic 3:
# university new member party zealand college minister politician professor labour
# Topic 4:
# international new zealand football represented player level loss association win
# Topic 5:
# new zealand olympics won games summer medal born competed commonwealth
# Topic 6:
# new zealand born world plays cup player league women team
# Topic 7:
# new zealand played cricket cricketer test class matches match born
# Topic 8:
# new zealand 2009 played national auckland 2005 australia born james
# Topic 9:
# new zealand played left team born cricket match australian class

# %%
# transform method returns a matrix with one line per document, columns being topics weight
predict = lda.transform(tf)
result = pd.DataFrame(predict).set_index(wiki_data.reset_index()['name'])

# %%
# get distribution of topics for Taika Waititi
d = pd.Series(result.loc["Taika Waititi"]).sort_values(ascending=False)

ax = d.plot(kind='bar', title='Taika Waititi Wikipedia Topic distribution',
            figsize=(10,6), width=.8, fontsize=14, rot=45 )

ax.title.set_size(20)
